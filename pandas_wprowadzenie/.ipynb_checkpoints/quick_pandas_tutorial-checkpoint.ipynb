# %%
# !dir
# Out:
#  Wolumin w stacji C nie ma etykiety.
#  Numer seryjny woluminu: 8C5A-2D9C
#
#  Katalog: C:\Users\kurs\PycharmProjects\pythonalx\pandas_wprowadzenie
#
# 2020-01-22  18:12    <DIR>          .
# 2020-01-22  18:12    <DIR>          ..
# 2020-01-22  18:08    <DIR>          .ipynb_checkpoints
# 2020-01-22  18:10               555 quick_pandas_tutorial.ipynb
# 2020-01-22  18:12         4˙115˙852 RegularSeasonCompactResults.csv
#                2 plik(˘w)          4˙116˙407 bajt˘w
#                3 katalog(˘w)  15˙420˙076˙032 bajt˘w wolnych

# %%
# !pip install pandas
# Out:
# ...
# You are using pip version 19.0.3, however version 19.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %% [markdown]
# ### odczyt i zapis

# %%
df = pd.read_csv("RegularSeasonCompactResults.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0         1985      20   1228      81   1328      64    N      0
# 1         1985      25   1106      77   1354      70    H      0
# 2         1985      25   1112      63   1223      56    H      0
# 3         1985      25   1165      70   1432      54    H      0
# 4         1985      25   1192      86   1447      74    H      0
# ...        ...     ...    ...     ...    ...     ...  ...    ...
# 145284    2016     132   1114      70   1419      50    N      0
# 145285    2016     132   1163      72   1272      58    N      0
# 145286    2016     132   1246      82   1401      77    N      1
# 145287    2016     132   1277      66   1345      62    N      0
# 145288    2016     132   1386      87   1433      74    N      0
#
# [145289 rows x 8 columns]

# %%
df.head(10)
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0    1985      20   1228      81   1328      64    N      0
# 1    1985      25   1106      77   1354      70    H      0
# 2    1985      25   1112      63   1223      56    H      0
# 3    1985      25   1165      70   1432      54    H      0
# 4    1985      25   1192      86   1447      74    H      0
# 5    1985      25   1218      79   1337      78    H      0
# 6    1985      25   1228      64   1226      44    N      0
# 7    1985      25   1242      58   1268      56    N      0
# 8    1985      25   1260      98   1133      80    H      0
# 9    1985      25   1305      97   1424      89    H      0

# %%
df.tail(2)
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 145287    2016     132   1277      66   1345      62    N      0
# 145288    2016     132   1386      87   1433      74    N      0

# %%
# df.to_excel("test.xlsx")

"""
ModuleNotFoundError                       Traceback (most recent call last)
<ipython-input-14-4fc885f78b7a> in <module>
----> 1 df.to_excel("test.xlsx")

c:\users\kurs\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
   2254             startcol=startcol,
   2255             freeze_panes=freeze_panes,
-> 2256             engine=engine,
   2257         )
   2258 

c:\users\kurs\appdata\local\programs\python\python37\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
    728             need_save = False
    729         else:
--> 730             writer = ExcelWriter(_stringify_path(writer), engine=engine)
    731             need_save = True
    732 

c:\users\kurs\appdata\local\programs\python\python37\lib\site-packages\pandas\io\excel\_openpyxl.py in __init__(self, path, engine, mode, **engine_kwargs)
     17     def __init__(self, path, engine=None, mode="w", **engine_kwargs):
     18         # Use the openpyxl module as the Excel writer.
---> 19         from openpyxl.workbook import Workbook
     20 
     21         super().__init__(path, mode=mode, **engine_kwargs)
...
...

ModuleNotFoundError: No module named 'openpyxl'
"""
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-4fc885f78b7a> in <module>
# ----> 1 df.to_excel("test.xlsx")
#
# c:\users\kurs\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2254             startcol=startcol,
#    2255             freeze_panes=freeze_panes,
# -> 2256             engine=engine,
#    2257         )
#    2258
#
# c:\users\kurs\appdata\local\programs\python\python37\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     728             need_save = False
#     729         else:
# ...

# %%
# !pip install openpyxl
# Out:
# ...
#   Running setup.py install for et-xmlfile: started
#     Running setup.py install for et-xmlfile: finished with status 'done'
#   Running setup.py install for openpyxl: started
#     Running setup.py install for openpyxl: finished with status 'done'
# ...
# You are using pip version 19.0.3, however version 19.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
df.to_excel("test.xlsx")

# %%
# df1 = pd.read_excel("test.xlsx")
# ....
# ImportError: Missing optional dependency 'xlrd'. Install xlrd >= 1.0.0 for Excel support Use pip or conda to install xlrd.
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-20-e4be5f8f793c> in <module>
# ----> 1 df1 = pd.read_excel("test.xlsx")
#
# c:\users\kurs\appdata\local\programs\python\python37\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# c:\users\kurs\appdata\local\programs\python\python37\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skip_footer, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     308
# ...

# %%
dir(pd)
# Out:
# ['Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseArray',
#  'SparseDataFrame',
#  'SparseDtype',
#  'SparseSeries',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_hashtable',
#  '_lib',
# ...

# %%
dir(df)
# Out:
# ['Daynum',
#  'Lscore',
#  'Lteam',
#  'Numot',
#  'Season',
#  'T',
#  'Wloc',
#  'Wscore',
#  'Wteam',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
# ...

# %%
# !pip install xlrd
# Out:
# ...
# You are using pip version 19.0.3, however version 19.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
df1 = pd.read_excel("test.xlsx")

# %%
slownik = {'cecha1': [1,10,1,10,10], 'cecha2': [1,11,111,111,111]}

# %%
pd.DataFrame(slownik)
# Out:
#    cecha1  cecha2
# 0       1       1
# 1      10      11
# 2       1     111
# 3      10     111
# 4      10     111

# %%
df.shape
# Out:
# (145289, 8)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=145289, step=1)

# %%
df.columns
# Out:
# Index(['Season', 'Daynum', 'Wteam', 'Wscore', 'Lteam', 'Lscore', 'Wloc',
#        'Numot'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['Season', 'Daynum', 'Wteam', 'Wscore', 'Lteam', 'Lscore', 'Wloc', 'Numot']

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0         1985      20   1228      81   1328      64    N      0
# 1         1985      25   1106      77   1354      70    H      0
# 2         1985      25   1112      63   1223      56    H      0
# 3         1985      25   1165      70   1432      54    H      0
# 4         1985      25   1192      86   1447      74    H      0
# ...        ...     ...    ...     ...    ...     ...  ...    ...
# 145284    2016     132   1114      70   1419      50    N      0
# 145285    2016     132   1163      72   1272      58    N      0
# 145286    2016     132   1246      82   1401      77    N      1
# 145287    2016     132   1277      66   1345      62    N      0
# 145288    2016     132   1386      87   1433      74    N      0
#
# [145289 rows x 8 columns]>

# %%
df.describe()
# Out:
#               Season         Daynum          Wteam         Wscore  \
# count  145289.000000  145289.000000  145289.000000  145289.000000
# mean     2001.574834      75.223816    1286.720646      76.600321
# std         9.233342      33.287418     104.570275      12.173033
# min      1985.000000       0.000000    1101.000000      34.000000
# 25%      1994.000000      47.000000    1198.000000      68.000000
# 50%      2002.000000      78.000000    1284.000000      76.000000
# 75%      2010.000000     103.000000    1379.000000      84.000000
# max      2016.000000     132.000000    1464.000000     186.000000
#
#                Lteam         Lscore          Numot
# count  145289.000000  145289.000000  145289.000000
# mean     1282.864064      64.497009       0.044387
# std       104.829234      11.380625       0.247819
# min      1101.000000      20.000000       0.000000
# 25%      1191.000000      57.000000       0.000000
# 50%      1280.000000      64.000000       0.000000
# ...

# %%
df.dtypes
# Out:
# Season     int64
# Daynum     int64
# Wteam      int64
# Wscore     int64
# Lteam      int64
# Lscore     int64
# Wloc      object
# Numot      int64
# dtype: object

# %%
df.max()
# Out:
# Season    2016
# Daynum     132
# Wteam     1464
# Wscore     186
# Lteam     1464
# Lscore     150
# Wloc         N
# Numot        6
# dtype: object

# %%
df.min()
# Out:
# Season    1985
# Daynum       0
# Wteam     1101
# Wscore      34
# Lteam     1101
# Lscore      20
# Wloc         A
# Numot        0
# dtype: object

# %%
df.mean()
# Out:
# Season    2001.574834
# Daynum      75.223816
# Wteam     1286.720646
# Wscore      76.600321
# Lteam     1282.864064
# Lscore      64.497009
# Numot        0.044387
# dtype: float64

# %%
df.Wscore.mean()
# Out:
# 76.60032074004226

# %%
df['Wscore'].mean() # zapis przydatny, gdy są np. spacje
# Out:
# 76.60032074004226

# %%
df['Wscore'].max() # zwraca max z kolumny
# Out:
# 186

# %%
df['Wscore'].idxmax() # zwraca nr wiersza od wartosci max z kolumny
# Out:
# 24970

# %%
df. Wloc.value_counts()
# Out:
# H    86471
# A    44229
# N    14589
# Name: Wloc, dtype: int64

# %% [markdown]
# ### Dostęp do danych
#
# wybieranie wierszy i kolumn

# %%
df['Wloc']
# Out:
# 0         N
# 1         H
# 2         H
# 3         H
# 4         H
#          ..
# 145284    N
# 145285    N
# 145286    N
# 145287    N
# 145288    N
# Name: Wloc, Length: 145289, dtype: object

# %%
df['Wloc'][0]
# Out:
# 'N'

# %%
df.loc[1, 'Wloc']
# Out:
# 'H'

# %%
df.loc[0:10, 'Wloc']
# Out:
# 0     N
# 1     H
# 2     H
# 3     H
# 4     H
# 5     H
# 6     N
# 7     N
# 8     H
# 9     H
# 10    H
# Name: Wloc, dtype: object

# %%
df.loc[0:5:2, 'Wloc']
# Out:
# 0    N
# 2    H
# 4    H
# Name: Wloc, dtype: object

# %%
df.loc[0:6:2, 'Daynum':'Lteam']
# Out:
#    Daynum  Wteam  Wscore  Lteam
# 0      20   1228      81   1328
# 2      25   1112      63   1223
# 4      25   1192      86   1447
# 6      25   1228      64   1226

# %%
df.loc[0:6:2, 'Daynum':'Wloc':2]
# Out:
#    Daynum  Wscore  Lscore
# 0      20      81      64
# 2      25      63      56
# 4      25      86      74
# 6      25      64      44

# %%
df2 = df.loc[:15:3, ['Season', 'Wscore', 'Lteam', 'Lscore', 'Wloc', 'Numot']]
df2
# Out:
#     Season  Wscore  Lteam  Lscore Wloc  Numot
# 0     1985      81   1328      64    N      0
# 3     1985      70   1432      54    H      0
# 6     1985      64   1226      44    N      0
# 9     1985      97   1424      89    H      0
# 12    1985      91   1411      72    H      0
# 15    1985      65   1368      62    H      0

# %%
df2 = df2.reset_index()
df2
# Out:
#    index  Season  Wscore  Lteam  Lscore Wloc  Numot
# 0      0    1985      81   1328      64    N      0
# 1      3    1985      70   1432      54    H      0
# 2      6    1985      64   1226      44    N      0
# 3      9    1985      97   1424      89    H      0
# 4     12    1985      91   1411      72    H      0
# 5     15    1985      65   1368      62    H      0

# %%
df2 = df.iloc[:15:3, [0,2,4,5]]
df2
# Out:
#     Season  Wteam  Lteam  Lscore
# 0     1985   1228   1328      64
# 3     1985   1165   1432      54
# 6     1985   1228   1226      44
# 9     1985   1305   1424      89
# 12    1985   1374   1411      72

# %%
df.loc[df['Wscore'].idxmax(), 'Lteam']
# Out:
# 1109

# %%
df['Season']
# Out:
# 0         1985
# 1         1985
# 2         1985
# 3         1985
# 4         1985
#           ...
# 145284    2016
# 145285    2016
# 145286    2016
# 145287    2016
# 145288    2016
# Name: Season, Length: 145289, dtype: int64

# %%
type(df['Season'])
# Out:
# pandas.core.series.Series

# %%
type(df[['Season']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### ćwiczenia
#
# * utworz nowy notatnik z ćwiczeniami
# * df = otwórz plik excela "test.xlsx" i wypisz 10 ostatnich wierszy
# * z df wybierz wiersze od setnego do 1000, ale co 20, zapisz w nowym DF
# * zresetuj indeksy, wybierz parzyste wiersze i kolumny

# %% [markdown]
# ### sortowanie

# %%
df.sort_values("Lscore", ascending=False)
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 17867     1989      92   1258     181   1109     150    H      0
# 16853     1989      68   1258     162   1109     144    A      0
# 22074     1990      96   1261     148   1258     141    H      0
# 24970     1991      68   1258     186   1109     140    H      0
# 1126      1985      65   1424     142   1429     140    A      0
# ...        ...     ...    ...     ...    ...     ...  ...    ...
# 85042     2005      66   1131      73   1216      22    H      0
# 103660    2009      26   1326      59   1359      22    H      0
# 89021     2006      44   1284      41   1343      21    A      0
# 49310     1997      66   1157      61   1204      21    H      0
# 100027    2008      66   1203      49   1387      20    H      0
#
# [145289 rows x 8 columns]

# %% [markdown]
# ### filtrowanie

# %%
df['Lscore'] > 100
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 145284    False
# 145285    False
# 145286    False
# 145287    False
# 145288    False
# Name: Lscore, Length: 145289, dtype: bool

# %%
df[df['Lscore'] > 100]
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 426       1985      40   1185     109   1156     105    H      0
# 1126      1985      65   1424     142   1429     140    A      0
# 3045      1985     113   1193     106   1247     105    A      0
# 3953      1986      33   1364     109   1109     101    H      0
# 4149      1986      39   1390     129   1463     108    H      0
# ...        ...     ...    ...     ...    ...     ...  ...    ...
# 143601    2016      94   1431     112   1267     108    H      0
# 143658    2016      96   1201     111   1424     104    H      2
# 144550    2016     115   1150     114   1427     108    H      2
# 144999    2016     124   1267     108   1379     106    H      1
# 145148    2016     128   1424     108   1102     102    N      3
#
# [501 rows x 8 columns]

# %%
df[(df['Lscore'] > 100) & (df['Lscore'] < 110)]
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 426       1985      40   1185     109   1156     105    H      0
# 3045      1985     113   1193     106   1247     105    A      0
# 3953      1986      33   1364     109   1109     101    H      0
# 4149      1986      39   1390     129   1463     108    H      0
# 5269      1986      75   1258     151   1109     107    H      0
# ...        ...     ...    ...     ...    ...     ...  ...    ...
# 143601    2016      94   1431     112   1267     108    H      0
# 143658    2016      96   1201     111   1424     104    H      2
# 144550    2016     115   1150     114   1427     108    H      2
# 144999    2016     124   1267     108   1379     106    H      1
# 145148    2016     128   1424     108   1102     102    N      3
#
# [379 rows x 8 columns]

# %% [markdown]
# ### ćwiczenia 2
#
# * wybierz te wiersze, które są z sezonów 1988, 89, 90, ktore maja Wloc = N, Lscore < 95, Wscore > 155

# %%
dir(df.Season)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
# ...

# %%
df[(df['Season'] >= 1988) & (df['Season'] <= 1990) & (df['Wloc'] == 'N') & (df['Lscore'] < 95) & (df['Wscore'] > 145)]
# Out:
#        Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 20590    1990      60   1328     147   1317      94    N      0

# %%
df[(df.Season.isin([1988, 1989, 1990])) & (df['Wloc'] == 'N') & (df['Lscore'] < 95) & (df['Wscore'] > 145)]
# Out:
#        Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 20590    1990      60   1328     147   1317      94    N      0

# %% [markdown]
# ### grupowanie

# %%
df.Wteam.value_counts()
# Out:
# 1181    819
# 1242    804
# 1246    765
# 1314    761
# 1112    746
#        ...
# 1101     18
# 1446     14
# 1118      6
# 1289      6
# 1327      3
# Name: Wteam, Length: 364, dtype: int64

# %%
df.groupby("Wloc")

# %%
df.groupby("Wloc")["Wscore"].mean()
# Out:
# Wloc
# A    74.781343
# H    77.739092
# N    75.365207
# Name: Wscore, dtype: float64

# %%
df["nowa"] = 0

# %%
df
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot  nowa
# 0         1985      20   1228      81   1328      64    N      0     0
# 1         1985      25   1106      77   1354      70    H      0     0
# 2         1985      25   1112      63   1223      56    H      0     0
# 3         1985      25   1165      70   1432      54    H      0     0
# 4         1985      25   1192      86   1447      74    H      0     0
# ...        ...     ...    ...     ...    ...     ...  ...    ...   ...
# 145284    2016     132   1114      70   1419      50    N      0     0
# 145285    2016     132   1163      72   1272      58    N      0     0
# 145286    2016     132   1246      82   1401      77    N      1     0
# 145287    2016     132   1277      66   1345      62    N      0     0
# 145288    2016     132   1386      87   1433      74    N      0     0
#
# [145289 rows x 9 columns]

# %%
df["nowa"][::3] = 1
df
# Out:
# c:\users\kurs\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot  nowa
# 0         1985      20   1228      81   1328      64    N      0     1
# 1         1985      25   1106      77   1354      70    H      0     0
# 2         1985      25   1112      63   1223      56    H      0     0
# 3         1985      25   1165      70   1432      54    H      0     1
# 4         1985      25   1192      86   1447      74    H      0     0
# ...        ...     ...    ...     ...    ...     ...  ...    ...   ...
# 145284    2016     132   1114      70   1419      50    N      0     1
# ...

# %%
import numpy as np

# %%
df.groupby("Season").agg({"Wscore": np.mean, 'Lteam': max})
# Out:
#            Wscore  Lteam
# Season
# 1985    74.723040   1464
# 1986    74.813640   1464
# 1987    77.993870   1464
# 1988    79.773704   1464
# 1989    81.728511   1464
# 1990    80.846477   1464
# 1991    82.733932   1464
# 1992    79.992004   1464
# 1993    79.508790   1464
# 1994    81.160345   1464
# 1995    80.096149   1464
# 1996    78.205483   1464
# 1997    76.300842   1464
# 1998    77.229902   1464
# 1999    76.043581   1464
# 2000    76.310467   1464
# 2001    77.088650   1464
# 2002    76.963557   1464
# 2003    75.795061   1464
# 2004    74.971122   1464
# 2005    74.693690   1464
# 2006    74.587555   1464
# 2007    74.829467   1464
# 2008    74.962425   1464
# 2009    74.033721   1464
# 2010    74.652480   1464
# 2011    74.374190   1464
# 2012    73.379973   1464
# 2013    72.840789   1464
# 2014    76.101268   1464
# 2015    72.680799   1464
# 2016    78.295958   1464

# %% [markdown]
# ## pogrupuj po sezonie i Wloc i zwroc agregacje - Wscore-max Lscore - min, nowa - średnia

# %%
df.groupby(["Season", "Wloc"]).agg({
    "Wscore": max, 
    'Lscore': min,
    'nowa': np.mean
})
# Out:
#              Wscore  Lscore      nowa
# Season Wloc
# 1985   A        142      35  0.327648
#        H        128      27  0.339572
#        N        121      37  0.313984
# 1986   A        126      30  0.323423
#        H        151      31  0.333333
# ...             ...     ...       ...
# 2015   H        126      26  0.338466
#        N        106      26  0.332734
# 2016   A        114      33  0.343544
#        H        144      25  0.325344
#        N        108      38  0.347826
#
# [96 rows x 3 columns]

# %%
df.groupby(["Season", "Wloc"]).agg({
    "Wscore": max, 
    'Lscore': min,
    'nowa': np.mean
})
